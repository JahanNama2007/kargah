# %% [markdown]
# MohammadAmin JahanNama
# 4042013050

# %%
main_students = {
        "first_name": "Ali",
        "last_name": "Rezaei",
        "student_code": "S12345",
        "date_of_birth": 1998,
        "age": 25,
        "desired_movie": "Inception",
        "desired_song": "Queen",
        "major": "Computer Engineering",
        "academic_level": "Msater",
        "entry_year": 2018,
        "gpa": 17.5,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "career_goal": "Software Developer",
        "strengths": ["Teamwork", "Problem-solving"],
        "weaknesses": ["Public speaking"],
        "favorite_book": "The Alchemist",
        "skills": ["Python", "C++"],
        "languages": ["English", "French"],
        "volunteer_experience": ["Teaching assistant"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}

# %%
student_1 = {
        "first_name": "MohammadAmin",
        "last_name": "JahanNama",
        "student_code": "4042013050",
        "date_of_birth": 2007,
        "desired_movie": "Titanic",
        "major": "Electrical Engineering",
        "academic_level": "Msc",
        "gpa": 19,
        "favorite_courses": ["Algorithms", "Data Structures"],
        "hobbies": ["Reading", "Football"],
        "feedback": {
            "courses": "Challenging but rewarding",
            "professors": "Supportive and knowledgeable"
        }
}

# %%
for i in student_1 :
    for j in main_students :
        if i == j  :
            main_students[j] = student_1[i]

# %%
print(main_students)
# Out:
# {'first_name': 'MohammadAmin', 'last_name': 'JahanNama', 'student_code': '4042013050', 'date_of_birth': 2007, 'age': 25, 'desired_movie': 'Titanic', 'desired_song': 'Queen', 'major': 'Electrical Engineering', 'academic_level': 'Msc', 'entry_year': 2018, 'gpa': 19, 'favorite_courses': ['Algorithms', 'Data Structures'], 'hobbies': ['Reading', 'Football'], 'career_goal': 'Software Developer', 'strengths': ['Teamwork', 'Problem-solving'], 'weaknesses': ['Public speaking'], 'favorite_book': 'The Alchemist', 'skills': ['Python', 'C++'], 'languages': ['English', 'French'], 'volunteer_experience': ['Teaching assistant'], 'feedback': {'courses': 'Challenging but rewarding', 'professors': 'Supportive and knowledgeable'}}
